# %%
# %matplotlib notebook

from pyhardrat import *
# Out:
# Configuration read from /Users/jburgess/.threeML/threeML_config.yml

# %% [markdown]
# ## Build the HR from a FERMIBURST Query
#
# First we create a HR builder object

# %%
hrb = HardnessDurationBuilder()

# %% [markdown]
# Put in a query on the online FERMIBURST catalog parameters. E.g. t90>0 should be all GRBs

# %%
hrb.catalog.query('.01<t90<20')
# Out:
# <Table masked=True length=1062>
#     name        ra     dec    trigger_time   t90
#    object    float64 float64    float64    float64
# ------------ ------- ------- ------------- -------
# GRB080714086  41.900   8.500 54661.0862506   5.376
# GRB080715950 214.700   9.900 54662.9504649   7.872
# GRB080719529 153.200 -61.300 54666.5289463  16.128
# GRB080723913 113.300 -19.700 54670.9134613   0.192
# GRB080725541 354.800   8.900 54672.5412473    0.96
# GRB080730520 245.400   4.600 54677.5203172  17.408
# GRB080730786 246.600  28.700 54677.7858586  13.312
# GRB080802386 154.300  40.700 54680.3855385   0.576
# GRB080806584  94.600  57.800 54684.5841575   2.304
# GRB080807993 101.700 -16.000 54685.9934333  19.072
#          ...     ...     ...           ...     ...
# GRB170801690 343.180 -41.750 57966.6900856   10.24
# GRB170802638  52.300 -39.210 57967.6377871    2.24
# GRB170803172  76.500  23.970   57968.17171   6.656
# GRB170803729 174.935 -16.312 57968.7294805   3.584
# ...

# %% [markdown]
# One we have our selection, we must go through and build the models. This routine selects the best fitting model (input 'fluence'[default] or 'peak') according the GBM online catalog. **This step can take a few minutes.**

# %%
hrb.build_sample()

# %% [markdown]
# Now select the intervals for the HRs. Both a photon and an energy HR are calculted.

# %%
hrb.compute_hardness_ratios(10,50,50,300)

# %% [markdown]
# We can view and access the data like so,

# %%
hrb.hr_table
# Out:
#                  T90   energy HR    photon HR
# GRB100325246   8.192    0.850681     4.552722
# GRB141004150   9.472    0.636379     2.377836
# GRB110716018   7.168    1.674461     5.671231
# GRB110819665  16.384    1.816246     6.287453
# GRB170304003   0.160    3.648233    12.581692
# GRB090304216   2.816    0.339559     1.866156
# GRB100604287  13.440    1.048601     4.179452
# GRB140213807  18.624    0.590775     2.683040
# GRB090725838  13.760    3.259919    11.868127
# GRB140322424  10.496   14.542467    49.535842
# GRB150902733  13.568    0.132253     0.670500
# GRB081226044   0.832    0.337339     1.854312
# GRB090606471   8.064    0.464001     2.526899
# GRB090513941  11.776    0.512219     2.781451
# GRB091102607   6.656    0.317350     1.747540
# GRB090120627   1.856    0.265782     1.471093
# GRB141022061  11.520    0.510619     2.773019
# GRB090819607   0.192    0.066890     0.338439
# GRB111107035  12.032    0.482964     2.627092
# ...

# %% [markdown]
# ## Plotting
#
# The plots are easy to obtain

# %%
_ = hrb.plot_photon()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
_ = hrb.plot_energy()
# Out:
# <img src="data:image/png;base64,..." width="640">
